# %%
import requests
import zipfile
import os
import pandas as pd

# %%
def generate_year_month_list(start_date, end_date):
    # Generate date range from start to end date
    date_range = pd.date_range(start=start_date, end=end_date, freq='MS')  # 'MS' for Month Start
    year_month_list = [(date.year, date.month) for date in date_range]
    return year_month_list

def download_and_unzip(url, dest_folder):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    # Download the file
    zip_path = os.path.join(dest_folder, 'downloaded.zip')
    response = requests.get(url, stream=True)
    with open(zip_path, 'wb') as file:
        for chunk in response.iter_content(chunk_size=128):
            file.write(chunk)
    print(f'Downloaded {zip_path}')
    
    # Unzip the file
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(dest_folder)
    print(f'Extracted contents to {dest_folder}')
    
    # Optionally remove the downloaded zip file
    os.remove(zip_path)
    print(f'Removed {zip_path}')

# %%
start_date = '2021-04-01'
end_date = '2024-12-31'
base_url='https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal'
# folder=r"B:\bich\SSEBop.v6.1" #ObjectStore
folder = r'E:\WaPORQA2\SSEBop.v6.1'

year_month_list = generate_year_month_list(start_date, end_date)

for year,month in year_month_list:
    for dekad in [1,2,3]:
        file="d{:04}{:02}{:01}.zip".format(year,month,dekad)
        url=f"{base_url}/{file}"
        print(url)        
        download_and_unzip(url, folder)
# Out:
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021041.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021042.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021043.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021051.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021052.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021053.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021061.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021062.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021063.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021071.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021072.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021073.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021081.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021082.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021083.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021091.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021092.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021093.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021101.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021102.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021103.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021111.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021112.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021113.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021121.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021122.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2021123.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022011.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022012.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022013.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022021.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022022.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022023.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022031.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022032.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022033.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022041.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022042.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022043.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022051.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022052.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022053.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022061.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022062.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022063.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022071.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022072.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022073.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022081.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022082.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022083.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022091.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022092.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022093.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022101.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022102.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022103.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022111.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022112.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022113.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022121.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022122.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2022123.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023011.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023012.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023013.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023021.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023022.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023023.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023031.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023032.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023033.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023041.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023042.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023043.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023051.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023052.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023053.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023061.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023062.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023063.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023071.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023072.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023073.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023081.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023082.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023083.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023091.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023092.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023093.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023101.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023102.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023103.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023111.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023112.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023113.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023121.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023122.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2023123.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024011.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024012.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024013.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024021.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024022.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024023.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024031.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024032.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024033.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024041.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024042.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024043.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024051.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024052.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024053.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024061.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024062.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024063.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024071.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024072.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024073.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024081.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024082.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024083.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024091.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024092.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024093.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024101.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024102.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024103.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024111.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024112.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024113.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024121.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024122.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2024123.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip

# %%
list_dekad=[
    (2019,5,3),
    (2019,7,3),
    (2019,8,1),
    (2020,5,3),
    (2020,8,1)
]
base_url='https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal'
# folder=r"B:\bich\SSEBop.v6.1" #ObjectStore
folder = r'E:\WaPORQA2\SSEBop.v6.1'

# year_month_list = generate_year_month_list(start_date, end_date)

for (year,month,dekad) in list_dekad:    
    file="d{:04}{:02}{:01}.zip".format(year,month,dekad)
    url=f"{base_url}/{file}"
    print(url)        
    download_and_unzip(url, folder)
# Out:
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2019053.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2019073.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2019081.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2020053.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/fews/web/global/dekadal/etav61/downloads/dekadal/d2020081.zip
# Downloaded E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
# Extracted contents to E:\WaPORQA2\SSEBop.v6.1
# Removed E:\WaPORQA2\SSEBop.v6.1\downloaded.zip
