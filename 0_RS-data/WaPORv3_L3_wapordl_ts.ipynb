# %%
import wapordl
import pandas as pd
import os

# %% [markdown]
# # Download ts at one point

# %%
variable = "L3-AETI-D"
period = ["2018-01-01", "2024-12-31"]
dx=5/(1000*111.31)

# %% [markdown]
# Sakha
#
# Lat	31° 5'48.69"N
#
# Long	30°55'20.97"E
#
#
# Sids
#
# Lat	28°54'43.30"N
#
# Long	30°57'22.80"E

# %%
lon = 30.922492
lat = 31.096858
bb = [lon-dx,lat-dx,lon+dx,lat+dx] #bounding box around the station
overview = "NONE"
df = wapordl.wapor_ts(bb, variable, period, overview)

df.to_csv('Sakha_L3.csv')
# Out:
# INFO: Given `region` matches with `ENO` L3 region.
# INFO: Found 252 files for L3-AETI-D.

# %%
lon = 30.956333
lat = 28.912028
bb = [lon-dx,lat-dx,lon+dx,lat+dx] #bounding box around the station
overview = "NONE"
df = wapordl.wapor_ts(bb, variable, period, overview)

df.to_csv('Sids_L3_overview_None_dx5.csv')
# Out:
# INFO: Given `region` matches with `ENO` L3 region.
# INFO: Found 252 files for L3-AETI-D.
