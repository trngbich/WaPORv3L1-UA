# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import seaborn as sns
# %run ..\Functions.ipynb

# %% [markdown]
# # Collocated dekadal data

# %%
folder1 = r'D:\Doctorate\Bich_PhD\research\3_WaPOR\Notebooks\0_RS-data\Data\WaPOR-CONUS'
folder2 = r'D:\Doctorate\Bich_PhD\research\3_WaPOR\Notebooks\0_RS-data\Data\OpenET'
name1 = 'WaPOR_v3_L1_AETI'
name2 = 'OpenET_Models'

# %%
# sites with OpenET model data from 2018
stations = ['ALARC2_Smith6', 'Almond_High', 'Almond_Low', 'Almond_Med', 'BAR012', 'Ellendale', 'JPL1_Smith5', 'manilacotton', 'RIP760', 'S2', 'SLM001', 'stonevillesoy', 'UA1_HartFarm', 'UA1_JV187', 'UA1_KN18', 'UA2_JV330', 'UA2_KN20', 'UA3_JV108', 'UA3_KN15', 'US-ARM', 'US-Bi1', 'US-Bi2', 'JPL1_JV114', 'US-IB1', 'US-Ne1', 'US-Ne2', 'US-Ne3', 'US-OF4', 'US-OF6', 'US-Tw3', 'US-xSL', 'US-Me2', 'US-Me6', 'US-NC2', 'US-NC3', 'US-NR1', 'US-xRM', 'US-xSB', 'US-Hn2', 'US-IB2', 'US-KM4', 'US-Ro4', 'US-SRG', 'US-Var', 'US-Wkg', 'US-xAE', 'US-xDC', 'US-xDS', 'US-xNG', 'US-MMS', 'US-WCr', 'US-xDL', 'US-xST', 'US-xUN', 'US-Hn3', 'US-Jo2', 'US-Rwf', 'US-Rws', 'US-SRM', 'US-SRS', 'US-CMW', 'US-NC4', 'US-Sne']
len(stations)
# Out:
# 63

# %%
station = 'US-Sne'
# get file paths
fh1 = os.path.join(folder1,name1+'_'+station+'.csv')
fh2 = os.path.join(folder2,name2+'_'+station+'.csv')

# %%
# get dataframes
df1 = pd.read_csv(fh1,parse_dates=True,index_col=4)
df1 = df1[['mean']]
df1 = df1.rename(columns = {'mean':'WaPORv3L1'})
df2 = pd.read_csv(fh2,parse_dates=True,index_col=0)           
# merge dataframes
df_merged = pd.merge(df1, df2, left_index=True, right_index=True, how='inner')
df_merged = df_merged.reset_index()
df_station = df_merged.rename(columns = {'index': 'Date'})
df_station.insert(0, 'Site ID', station)
df_station
# Out:
#    Site ID       Date  WaPORv3L1  geeSEBAL    PT-JPL    SSEBop  SIMS  \
# 0   US-Sne 2018-03-01        1.3  2.768750  3.618750  2.587500   NaN
# 1   US-Sne 2018-03-11        1.2  3.400000  4.033333  3.133333   NaN
# 2   US-Sne 2018-03-21        2.2  4.850000  4.987500  4.606250   NaN
# 3   US-Sne 2018-04-01        2.6  5.125000  5.468750  4.640625   NaN
# 4   US-Sne 2018-04-11        2.6  5.750000  6.262500  5.000000   NaN
# ..     ...        ...        ...       ...       ...       ...   ...
# 58  US-Sne 2019-10-11        2.2  2.411250  3.043750  3.745000   NaN
# 59  US-Sne 2019-10-21        2.7  1.897727  2.846591  3.039773   NaN
# 60  US-Sne 2019-11-01        1.4  1.221250  2.247500  2.476250   NaN
# 61  US-Sne 2019-11-11        1.2  0.896875  2.267187  2.534375   NaN
# 62  US-Sne 2019-11-21        0.9       NaN       NaN       NaN   NaN
#
#     eeMETRIC  DisALEXI  Ensemble
# 0   2.737500  3.843750  2.968750
# 1   3.433333  4.466667  3.500000
# 2   5.231250  6.012500  4.931250
# 3   4.853125  6.081250  5.103125
# 4   4.575000  6.462500  5.625000
# ..       ...       ...       ...
# 58  4.597500  3.401250  3.492500
# 59  3.293182  3.063636  3.027273
# 60  2.217500  2.491250  2.337500
# 61  2.604688  1.826563  2.300000
# 62       NaN       NaN       NaN
#
# [63 rows x 10 columns]

# %%
df_all = pd.DataFrame(columns=['Site ID', 'Date', 'WaPORv3L1', 
                               'geeSEBAL', 'PT-JPL', 'SSEBop', 'SIMS',
                               'eeMETRIC', 'DisALEXI', 'Ensemble'])
for i,station in enumerate(stations):
    # get file paths
    fh1 = os.path.join(folder1,name1+'_'+station+'.csv')
    fh2 = os.path.join(folder2,name2+'_'+station+'.csv')
    # get dataframes
    try:
        # get dataframes
        df1 = pd.read_csv(fh1,parse_dates=True,index_col=4)
        df1 = df1[['mean']]
        df1 = df1.rename(columns = {'mean':'WaPORv3L1'})
        df2 = pd.read_csv(fh2,parse_dates=True,index_col=0)   
    except:
        continue
    # merge dataframes
    df_merged = pd.merge(df1, df2, left_index=True, right_index=True, how='inner')
    df_merged = df_merged.reset_index()
    df_station = df_merged.rename(columns = {'index': 'Date'})
    df_station.insert(0, 'Site ID', station)   
    #append df_station
    if len(df_station)>0:
        df_all = pd.concat([df_all, df_station], ignore_index=True)
# Out:
# C:\Users\ntr002\AppData\Local\Temp\ipykernel_11988\3085644607.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all = pd.concat([df_all, df_station], ignore_index=True)

# %%
df_all
# Out:
#             Site ID       Date  WaPORv3L1  geeSEBAL    PT-JPL    SSEBop  \
# 0     ALARC2_Smith6 2018-03-01       2.20  3.940833  4.152083  4.044167
# 1     ALARC2_Smith6 2018-03-11       2.30  4.325000  4.400000  5.100000
# 2     ALARC2_Smith6 2018-03-21       2.75  5.337500  5.037500  7.725000
# 3     ALARC2_Smith6 2018-04-01       3.10  5.715625  5.415625  8.068750
# 4     ALARC2_Smith6 2018-04-11       3.10  6.200000  6.100000  7.250000
# ...             ...        ...        ...       ...       ...       ...
# 2761         US-Sne 2019-10-11       2.20  2.411250  3.043750  3.745000
# 2762         US-Sne 2019-10-21       2.70  1.897727  2.846591  3.039773
# 2763         US-Sne 2019-11-01       1.40  1.221250  2.247500  2.476250
# 2764         US-Sne 2019-11-11       1.20  0.896875  2.267187  2.534375
# 2765         US-Sne 2019-11-21       0.90       NaN       NaN       NaN
#
#           SIMS  eeMETRIC  DisALEXI  Ensemble
# 0     3.259167  4.442500  3.807083  3.976667
# 1     4.175000  5.225000  4.475000  4.637500
# 2     6.387500  7.487500  6.100000  6.212500
# 3     6.628125  8.553125  6.100000  6.246875
# 4     6.250000  8.250000  6.200000  6.250000
# ...        ...       ...       ...       ...
# 2761       NaN  4.597500  3.401250  3.492500
# 2762       NaN  3.293182  3.063636  3.027273
# 2763       NaN  2.217500  2.491250  2.337500
# 2764       NaN  2.604688  1.826563  2.300000
# 2765       NaN       NaN       NaN       NaN
#
# [2766 rows x 10 columns]

# %%
plt.scatter(df_all['Ensemble'],df_all['WaPORv3L1'])

# %%
plt.plot(df_all.index,df_all['Ensemble'],label='Ensemble')
plt.plot(df_all.index,df_all['WaPORv3L1'],label='WaPOR v3 L1')
plt.legend()

# %% [markdown]
# # Scatterplot

# %%
# --- Custom Function for Annotations ---
def corrfunc(x, y, **kws):
    """
    Calculates and annotates the plot with Pearson r and p-value.
    """
    # Calculate the correlation coefficient and the p-value
    (r, p) = pearsonr(x, y)
    rmsd = np.sqrt(np.mean((x - y) ** 2))
    # Get the current axes
    ax = plt.gca()
    
    # Define the annotation text
    annotation_text = f'$\\rho$ = {r:.2f}\nRMSD = {rmsd:.2f} '+'(mm $d^{-1})$'
    
    # Add the annotation to the plot
    # xy=(.1, .9) places the text at the top-left corner of the subplot
    ax.annotate(annotation_text,
                xy=(.1, .5), 
                xycoords=ax.transAxes,
                fontsize = 12,
                ha='left', 
                va='top')

# %%
df_triple= df_all[['WaPORv3L1','geeSEBAL','PT-JPL','SSEBop','eeMETRIC','DisALEXI']].dropna()
# --- Create the PairGrid Plot ---
plt.figure(figsize=(7, 7))
sns.set_style("darkgrid")
plt.rcParams.update({'font.size': 14})
# 1. Initialize a PairGrid object
g = sns.PairGrid(df_triple, corner=False)

# 2. Map plots to the different sections of the grid
# Scatter plots on the lower triangle
g.map_lower(sns.scatterplot, s=40, alpha=0.7)

# Histograms on the diagonal
g.map_diag(sns.histplot, kde=True)

# Our custom function on the upper triangle
g.map_upper(corrfunc)

# Add a title for the entire plot
# g.fig.suptitle('Correlogram with Correlation Coefficients and P-Values at 215 EC sites', y=1.02)

# 3. Show the plot
plt.savefig('Data/scatterplot_TCH_assumptions_OpenET.png')
plt.show()

# %% [markdown]
# # Calculate performance metrics - all data points

# %%
import model_evaluation.double_collocation as dc
import model_evaluation.triple_collocation as tc

# %%
df_all.isna().sum() #number of nans in each column
# Out:
# Site ID         0
# Date            0
# WaPORv3L1       0
# geeSEBAL      856
# PT-JPL        856
# SSEBop        856
# SIMS         1799
# eeMETRIC      856
# DisALEXI      856
# Ensemble      856
# dtype: int64

# %% [markdown]
# Thus, selected models for Triple collocation:
#
# ['geeSEBAL','PT-JPL','SSEBop','eeMETRIC','DisALEXI']

# %%
import itertools
models = ['geeSEBAL','PT-JPL','SSEBop','eeMETRIC','DisALEXI']
for x in itertools.product(models, models):
    if x[0]!=x[1]:
        print(x)
# Out:
# ('geeSEBAL', 'PT-JPL')
# ('geeSEBAL', 'SSEBop')
# ('geeSEBAL', 'eeMETRIC')
# ('geeSEBAL', 'DisALEXI')
# ('PT-JPL', 'geeSEBAL')
# ('PT-JPL', 'SSEBop')
# ('PT-JPL', 'eeMETRIC')
# ('PT-JPL', 'DisALEXI')
# ('SSEBop', 'geeSEBAL')
# ('SSEBop', 'PT-JPL')
# ('SSEBop', 'eeMETRIC')
# ('SSEBop', 'DisALEXI')
# ('eeMETRIC', 'geeSEBAL')
# ('eeMETRIC', 'PT-JPL')
# ('eeMETRIC', 'SSEBop')
# ('eeMETRIC', 'DisALEXI')
# ('DisALEXI', 'geeSEBAL')
# ('DisALEXI', 'PT-JPL')
# ('DisALEXI', 'SSEBop')
# ('DisALEXI', 'eeMETRIC')

# %%
list_couples = [('geeSEBAL', 'PT-JPL'),
('geeSEBAL', 'SSEBop'),
('geeSEBAL', 'eeMETRIC'),
('geeSEBAL', 'DisALEXI'),
('PT-JPL', 'SSEBop'),
('PT-JPL', 'eeMETRIC'),
('PT-JPL', 'DisALEXI'),
('SSEBop', 'eeMETRIC'),
('SSEBop', 'DisALEXI'),
('eeMETRIC', 'DisALEXI')]

# %%
all_stderr = {}
all_rho = {}
for couple in list_couples:
    columns = ['Site ID','WaPORv3L1','Date']+list(couple)
    df_triple = df_all[columns]
    df_triple = df_triple.dropna()
    ts1=df_triple['WaPORv3L1']
    ts2=df_triple[couple[0]]
    ts3=df_triple[couple[1]]
    q_hat = tc.covariance_matrix(ts1, ts2, ts3)
    stderr, rho, snr_db, sensitivity = tc.etc(q_hat)
    all_stderr[couple]= stderr[0]
    all_rho[couple]= rho[0]
# Out:
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s

# %%
all_stderr
# Out:
# {('geeSEBAL', 'PT-JPL'): np.float64(0.9657233516467175),
#  ('geeSEBAL', 'SSEBop'): np.float64(1.0220369103105218),
#  ('geeSEBAL', 'eeMETRIC'): np.float64(1.0535748007780132),
#  ('geeSEBAL', 'DisALEXI'): np.float64(1.0200425572724614),
#  ('PT-JPL', 'SSEBop'): np.float64(0.9755565120730593),
#  ('PT-JPL', 'eeMETRIC'): np.float64(0.9727491004793113),
#  ('PT-JPL', 'DisALEXI'): np.float64(0.9587294761526485),
#  ('SSEBop', 'eeMETRIC'): np.float64(1.0654188872212245),
#  ('SSEBop', 'DisALEXI'): np.float64(1.0299576667495844),
#  ('eeMETRIC', 'DisALEXI'): np.float64(1.0216049813546857)}

# %%
all_rho
# Out:
# {('geeSEBAL', 'PT-JPL'): np.float64(0.7707621420030154),
#  ('geeSEBAL', 'SSEBop'): np.float64(0.7384802419670786),
#  ('geeSEBAL', 'eeMETRIC'): np.float64(0.718930643207642),
#  ('geeSEBAL', 'DisALEXI'): np.float64(0.7396794497176697),
#  ('PT-JPL', 'SSEBop'): np.float64(0.7653533721380794),
#  ('PT-JPL', 'eeMETRIC'): np.float64(0.7669070882881572),
#  ('PT-JPL', 'DisALEXI'): np.float64(0.7745531018305224),
#  ('SSEBop', 'eeMETRIC'): np.float64(0.7112928405878223),
#  ('SSEBop', 'DisALEXI'): np.float64(0.7336748323664739),
#  ('eeMETRIC', 'DisALEXI'): np.float64(0.7387403255110834)}

# %% [markdown]
# # Calculate performance metrics - per sites

# %%
sites=list(df_all['Site ID'].unique())
len(sites)
# Out:
# 57

# %%
sites_stderr = {'Site ID':[]}
sites_rho = {'Site ID':[]}
for couple in list_couples:
    sites_stderr[couple]=[]
    sites_rho[couple]=[]

for site in sites:
    df_site = df_all[df_all['Site ID']==site]
    sites_stderr['Site ID']+=[site]
    sites_rho['Site ID']+=[site]
    for couple in list_couples:
        columns = ['WaPORv3L1','Date']+list(couple)
        df_triple = df_site[columns]
        df_triple = df_triple.dropna()
        ts1=df_triple['WaPORv3L1']
        ts2=df_triple[couple[0]]
        ts3=df_triple[couple[1]]
        q_hat = tc.covariance_matrix(ts1, ts2, ts3)
        stderr, rho, snr_db, sensitivity = tc.etc(q_hat)
        sites_stderr[couple]+= [stderr[0]]
        sites_rho[couple]+= [rho[0]]
# Out:
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=60, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=94, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=8, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=69, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=31, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=7, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=4, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=6, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=3, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=9, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=64, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=63, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=85, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=10, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=53, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=51, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=2, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=13, Consider increasing your sample size for robust TC metrics
# ...
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=26, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=26, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=26, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# Warning: Sample size is too small (n=52, Consider increasing your sample size for robust TC metrics
# Processed etc in  0.00 s
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:90: RuntimeWarning: invalid value encountered in sqrt
#   rho = (np.sqrt(q_hat[0, 1] * q_hat[0, 2] / (q_hat[0, 0] * q_hat[1, 2])),
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:91: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 2] * q_hat[1, 2]) * np.sqrt(q_hat[0, 1]
# C:\Users\ntr002\.conda\envs\phd\Lib\site-packages\model_evaluation-0.1a0-py3.12.egg\model_evaluation\triple_collocation.py:93: RuntimeWarning: invalid value encountered in sqrt
#   np.sign(q_hat[0, 1] * q_hat[1, 2]) * np.sqrt(q_hat[0, 2]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Error:</b> The time-series size per site is too small (<100 dekads) for triple collocation.
# </div>

# %%
sites_stderr = {'Site ID':[]}
sites_rho = {'Site ID':[]}
for couple in list_couples:
    sites_stderr[couple]=[]
    sites_rho[couple]=[]

for site in sites:
    df_site = df_all[df_all['Site ID']==site]
    sites_stderr['Site ID']+=[site]
    sites_rho['Site ID']+=[site]
    for couple in list_couples:
        columns = ['WaPORv3L1','Date']+list(couple)
        df_triple = df_site[columns]
        df_triple = df_triple.dropna()
        if len(df_triple)<100:
            sites_stderr[couple]+= [np.nan]
            sites_rho[couple]+= [np.nan] 
            continue
        ts1=df_triple['WaPORv3L1']
        ts2=df_triple[couple[0]]
        ts3=df_triple[couple[1]]
        q_hat = tc.covariance_matrix(ts1, ts2, ts3)
        stderr, rho, snr_db, sensitivity = tc.etc(q_hat)
        sites_stderr[couple]+= [stderr[0]]
        sites_rho[couple]+= [rho[0]]
# Out:
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s

# %%
sites_stderr
# Out:
# {'Site ID': ['ALARC2_Smith6',
#   'Almond_High',
#   'Almond_Low',
#   'Almond_Med',
#   'BAR012',
#   'JPL1_Smith5',
#   'manilacotton',
#   'RIP760',
#   'S2',
#   'SLM001',
#   'stonevillesoy',
#   'UA1_HartFarm',
#   'UA1_JV187',
#   'UA1_KN18',
#   'UA2_JV330',
#   'UA2_KN20',
#   'UA3_JV108',
#   'UA3_KN15',
#   'US-ARM',
#   'US-Bi1',
#   'US-Bi2',
#   'US-IB1',
#   'US-Ne1',
#   'US-Ne2',
#   'US-Ne3',
#   'US-OF6',
#   'US-Tw3',
#   'US-xSL',
#   'US-Me6',
#   'US-NC2',
#   'US-NC3',
#   'US-NR1',
#   'US-xSB',
#   'US-Hn2',
#   'US-IB2',
#   'US-Ro4',
#   'US-SRG',
#   'US-Var',
#   'US-Wkg',
#   'US-xAE',
#   'US-xDC',
#   'US-xDS',
#   'US-xNG',
#   'US-MMS',
#   'US-WCr',
#   'US-xDL',
#   'US-xST',
#   'US-xUN',
#   'US-Hn3',
#   'US-Jo2',
#   'US-Rwf',
#   'US-Rws',
#   'US-SRM',
#   'US-SRS',
#   'US-CMW',
#   'US-NC4',
#   'US-Sne'],
#  ('geeSEBAL', 'PT-JPL'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.30139780297545327),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('geeSEBAL', 'SSEBop'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.2661574567286704),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('geeSEBAL', 'eeMETRIC'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.27643097341540274),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('geeSEBAL', 'DisALEXI'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.3090245337922612),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('PT-JPL', 'SSEBop'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.25926244601492987),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('PT-JPL', 'eeMETRIC'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.2737883160498249),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('PT-JPL', 'DisALEXI'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.29612245993819725),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('SSEBop', 'eeMETRIC'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.2813420549853842),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('SSEBop', 'DisALEXI'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.28566179156099875),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ('eeMETRIC', 'DisALEXI'): [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   np.float64(0.2917244966589117),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]}

# %%
len(sites_stderr['Site ID'])
# Out:
# 57

# %% [markdown]
# # Calculate performance metrics - per land cover type

# %%
metadata = pd.read_excel(r"..\0_insitu\fluxqaqc_station_metadata.xlsx",skiprows=1)
metadata
# Out:
#     Site ID General classification State Data source/network Period of record  \
# 0    US-A32             Grasslands    OK           AmeriFlux  06/2015-06/2017
# 1    US-A74              Croplands    OK           AmeriFlux  01/2016-10/2017
# 2    US-ADR             Shrublands    NV           AmeriFlux  05/2011-05/2017
# 3    US-AR1              Croplands    OK           AmeriFlux  06/2009-12/2012
# 4    US-ARb             Grasslands    OK           AmeriFlux  03/2005-10/2006
# ..      ...                    ...   ...                 ...              ...
# 156   UOVLO             Shrublands    NV           USGS NWSC  07/1998-09/2000
# 157   UOVMD             Grasslands    NV           USGS NWSC  12/1998-09/2000
# 158   UOVUP             Shrublands    NV           USGS NWSC  01/1998-09/2000
# 159   WRV_1             Shrublands    NV           USGS NWSC  09/2005-08/2007
# 160   WRV_2             Shrublands    NV           USGS NWSC  09/2006-08/2007
#
#      Energy balance   Latitude   Longitude  Elevation (m)  \
# 0          0.903129  36.819268  -97.819772          335.0
# 1          0.920941  36.808464  -97.548854          337.0
# 2          0.919211  36.765278 -116.693333          842.0
# 3          1.089527  36.426700  -99.420000          611.0
# 4          1.005785  35.549700  -98.040200          424.0
# ..              ...        ...         ...            ...
# 156             NaN  37.045000 -116.709000         1177.0
# 157             NaN  37.047000 -116.712000         1175.0
# 158             NaN  37.064000 -116.695000         1198.0
# 159        0.994121  38.413600 -115.050900         1600.0
# 160        0.824748  38.640500 -115.102600         1622.0
#
#            Land cover details Land cover type Measurement technique  \
# 0                 Hay pasture      Grasslands       Eddy covariance
# 1                     Sorghum    Annual crops       Eddy covariance
# 2                  Greasewood      Shrublands       Eddy covariance
# 3         Planted Switchgrass    Annual crops       Eddy covariance
# 4    Native tallgrass prairie      Grasslands       Eddy covariance
# ..                        ...             ...                   ...
# 156                Greasewood      Shrublands       Eddy covariance
# 157                Salt Grass      Grasslands       Eddy covariance
# 158     Wolfberry/Rabbitbrush      Shrublands       Eddy covariance
# 159                Greasewood      Shrublands       Eddy covariance
# 160                Greasewood      Shrublands       Eddy covariance
#
#     Contact for sites not downloaded from AmeriFlux network  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 156                                    Steve R. Reiner
# 157                                    Steve R. Reiner
# 158                                    Steve R. Reiner
# 159                                   Michael T. Moreo
# 160                                   Michael T. Moreo
#
#          Contact email                   DOI      Team member Member role  \
# 0                  NaN  10.17190/AMF/1436327    Lara Kueppers          PI
# 1                  NaN  10.17190/AMF/1436328    Lara Kueppers          PI
# 2                  NaN  10.17190/AMF/1418680    Michael Moreo          PI
# 3                  NaN  10.17190/AMF/1246137  Dave Billesbach          PI
# 4                  NaN  10.17190/AMF/1246025    Margaret Torn          PI
# ..                 ...                   ...              ...         ...
# 156  srreiner@usgs.gov     10.3133/wri014239              NaN         NaN
# 157  srreiner@usgs.gov     10.3133/wri014239              NaN         NaN
# 158  srreiner@usgs.gov     10.3133/wri014239              NaN         NaN
# 159   mtmoreo@usgs.gov   10.3133/sir20075078              NaN         NaN
# 160   mtmoreo@usgs.gov   10.3133/sir20075078              NaN         NaN
#
#                         Member institution          Member email  \
# 0    Lawrence Berkeley National Laboratory    lmkueppers@lbl.gov
# 1    Lawrence Berkeley National Laboratory    lmkueppers@lbl.gov
# 2                   U.S. Geological Survey      mtmoreo@usgs.gov
# 3                   University of Nebraska  dbillesbach1@unl.edu
# 4    Lawrence Berkeley National Laboratory        mstorn@lbl.gov
# ..                                     ...                   ...
# 156                                    NaN                   NaN
# 157                                    NaN                   NaN
# 158                                    NaN                   NaN
# 159                                    NaN                   NaN
# 160                                    NaN                   NaN
#
#                                        Site name
# 0                    ARM-SGP Medford hay pasture
# 1                             ARM SGP milo field
# 2           Amargosa Desert Research Site (ADRS)
# 3        ARM USDA UNL OSU Woodward Switchgrass 1
# 4    ARM Southern Great Plains burn site- Lamont
# ..                                           ...
# 156                                          NaN
# 157                                          NaN
# 158                                          NaN
# 159                                          NaN
# 160                                          NaN
#
# [161 rows x 20 columns]

# %%
used_sites=metadata[metadata['Site ID'].isin(sites)]
used_sites.to_csv(r'../0_insitu/OpenET_sites_used.csv')

# %%
LCCs = []
for i,row in df_all.iterrows():
    site = row['Site ID']
    LCC = metadata[metadata['Site ID']==site]['Land cover type'].values[0]
    LCCs.append(LCC)
df_all['LCC']=LCCs

# %%
LCCs=list(df_all['LCC'].unique())
LCCs
# Out:
# ['Annual crops',
#  'Orchards',
#  'Vineyards',
#  'Vegetable crops',
#  'Evergreen Forests',
#  'Grasslands',
#  'Mixed Forests',
#  'Shrublands',
#  'Riparian',
#  'Wetlands']

# %%
list_couples = [('geeSEBAL', 'PT-JPL'),
('geeSEBAL', 'SSEBop'),
('geeSEBAL', 'eeMETRIC'),
('geeSEBAL', 'DisALEXI'),
('PT-JPL', 'SSEBop'),
('PT-JPL', 'eeMETRIC'),
('PT-JPL', 'DisALEXI'),
('SSEBop', 'eeMETRIC'),
('SSEBop', 'DisALEXI'),
('eeMETRIC', 'DisALEXI')]

# %%
LCC_stderr = {'LCC':[]}
LCC_rho = {'LCC':[]}
for couple in list_couples:
    LCC_stderr[couple]=[]
    LCC_rho[couple]=[]

for LCC in LCCs:
    df_site = df_all[df_all['LCC']==LCC]
    df_site.plot(x='Date',style='.')
    plt.title(LCC)
    LCC_stderr['LCC']+=[LCC]
    LCC_rho['LCC']+=[LCC]
    for couple in list_couples:
        columns = ['WaPORv3L1','Date']+list(couple)
        df_triple = df_site[columns]
        df_triple = df_triple.dropna()
        if len(df_triple)<100:
            LCC_stderr[couple]+= [np.nan]
            LCC_rho[couple]+= [np.nan] 
            continue
        ts1=df_triple['WaPORv3L1']
        ts2=df_triple[couple[0]]
        ts3=df_triple[couple[1]]
        q_hat = tc.covariance_matrix(ts1, ts2, ts3)
        stderr, rho, snr_db, sensitivity = tc.etc(q_hat)
        LCC_stderr[couple]+= [stderr[0]]
        LCC_rho[couple]+= [rho[0]]
# Out:
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Warning: At least one calculated error variance is negative. This can happen if the sample size is too small, or if one of the assumptions of CTC is violated.
# Processed etc in  0.00 s
# Processed etc in  0.00 s
# Processed etc in  0.00 s

# %%
pd.DataFrame(LCC_stderr).to_csv('Data/TC_dekad_stderr.csv')
pd.DataFrame(LCC_stderr)
# Out:
#                  LCC  (geeSEBAL, PT-JPL)  (geeSEBAL, SSEBop)  \
# 0       Annual crops            1.237825            1.371955
# 1           Orchards            0.424558            0.329202
# 2          Vineyards            0.704642            0.618284
# 3    Vegetable crops                 NaN                 NaN
# 4  Evergreen Forests            0.752133            0.966295
# 5         Grasslands            0.635997            0.579998
# 6      Mixed Forests            0.791090            0.730532
# 7         Shrublands            0.496273            0.493980
# 8           Riparian                 NaN                 NaN
# 9           Wetlands                 NaN                 NaN
#
#    (geeSEBAL, eeMETRIC)  (geeSEBAL, DisALEXI)  (PT-JPL, SSEBop)  \
# 0              1.341663              1.321345          1.199934
# 1              0.281709              0.400776          0.387877
# 2              0.781375              0.723060          0.709567
# 3                   NaN                   NaN               NaN
# 4              0.947267              0.977673          0.682969
# 5              0.719099              0.709434          0.667240
# 6              0.827449              0.740133          0.828687
# 7              0.603086              0.547724          0.434005
# 8                   NaN                   NaN               NaN
# 9                   NaN                   NaN               NaN
#
#    (PT-JPL, eeMETRIC)  (PT-JPL, DisALEXI)  (SSEBop, eeMETRIC)  \
# 0            1.177774            1.152441            1.338406
# 1            0.297108            0.444039            0.333260
# 2            0.675996            0.789413            0.739523
# 3                 NaN                 NaN                 NaN
# 4            0.639730            0.710871            1.060063
# 5            0.702102            0.719060            0.672329
# 6            0.744360            0.743886            0.898389
# 7            0.486550            0.486074            0.536534
# 8                 NaN                 NaN                 NaN
# 9                 NaN                 NaN                 NaN
#
#    (SSEBop, DisALEXI)  (eeMETRIC, DisALEXI)
# 0            1.298313              1.244813
# 1            0.397473              0.323768
# 2            0.688532              0.691099
# 3                 NaN                   NaN
# 4            1.092410              1.032417
# 5            0.695219              0.737309
# 6            0.678399              0.427704
# 7            0.497448              0.564117
# 8                 NaN                   NaN
# 9                 NaN                   NaN

# %%
pd.DataFrame(LCC_rho).to_csv('Data/TC_dekad_rho.csv')
pd.DataFrame(LCC_rho)
# Out:
#                  LCC  (geeSEBAL, PT-JPL)  (geeSEBAL, SSEBop)  \
# 0       Annual crops            0.712345            0.628413
# 1           Orchards            0.917859            0.951464
# 2          Vineyards            0.899760            0.923789
# 3    Vegetable crops                 NaN                 NaN
# 4  Evergreen Forests            0.856312            0.748164
# 5         Grasslands            0.809757            0.844788
# 6      Mixed Forests            0.915639            0.928541
# 7         Shrublands            0.742573            0.745353
# 8           Riparian                 NaN                 NaN
# 9           Wetlands                 NaN                 NaN
#
#    (geeSEBAL, eeMETRIC)  (geeSEBAL, DisALEXI)  (PT-JPL, SSEBop)  \
# 0              0.649099              0.662361          0.732891
# 1              0.964697              0.927157          0.931939
# 2              0.875121              0.894138          0.898275
# 3                   NaN                   NaN               NaN
# 4              0.759551              0.741162          0.883216
# 5              0.748234              0.756047          0.788067
# 6              0.907302              0.926576          0.907010
# 7              0.580979              0.673482          0.810507
# 8                   NaN                   NaN               NaN
# 9                   NaN                   NaN               NaN
#
#    (PT-JPL, eeMETRIC)  (PT-JPL, DisALEXI)  (SSEBop, eeMETRIC)  \
# 0            0.744357            0.756997            0.651256
# 1            0.960651            0.909767            0.950228
# 2            0.908150            0.872349            0.888959
# 3                 NaN                 NaN                 NaN
# 4            0.898352            0.872774            0.685683
# 5            0.761851            0.748266            0.784377
# 6            0.925701            0.925799            0.889709
# 7            0.754201            0.754760            0.689695
# 8                 NaN                 NaN                 NaN
# 9                 NaN                 NaN                 NaN
#
#    (SSEBop, DisALEXI)  (eeMETRIC, DisALEXI)
# 0            0.676845              0.708419
# 1            0.928399              0.953092
# 2            0.904531              0.903780
# 3                 NaN                   NaN
# 4            0.661311              0.705292
# 5            0.767205              0.732994
# 6            0.938699              0.976095
# 7            0.741140              0.648369
# 8                 NaN                   NaN
# 9                 NaN                   NaN
